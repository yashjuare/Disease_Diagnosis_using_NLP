# %% [markdown]
# ### In this notebook we will perform the word embedding & topic modeling & Cosine Similarity
#
# ***we merged the **three** chapters to perform the topic modeling, in order to perform cosine similarity to select which chapter the new input should go with.***

# %%
import pandas as pd
import numpy as np
import pickle

# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF

# %% [markdown]
# ### Read the data and pickle file

# %%
df02 = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\Diagnosis\Notebook\Current Medical Diagnosis1.csv')

# %%
# reading the stop words list with pickle
with open (r'C:\Users\HP\OneDrive\Desktop\Diagnosis\Notebook\current medical diagnosis1.ob', 'rb') as fp:
    stop_words = pickle.load(fp)

# %%
df02.head(10)
# Out:
#                                        string_values
# 0  prevention health promotion tobacco tobacco ht...
# 1  diabetes life islet west diabetes mellitust yp...
# 2  beverage brainstem aura blindness field thria ...
# 3  kidney proteinuria found overload proteinuria ...
# 4  chapter ated bp reading office pharmacy coat o...
# 5  chapter per redness swelling conjunctiva compr...

# %%
# Declare a list that is to be converted into a column
ch_no = ['Cancer','Diabetes', 'Nervous System', 'Kidney Disease', 'Hypertension', 'Ear, Nose, & Throat Disorders ']
# Using 'ch_no' as the column name
# and equating it to the list
df02['Topic'] = ch_no

# %%
df02
# Out:
#                                        string_values  \
# 0  prevention health promotion tobacco tobacco ht...
# 1  diabetes life islet west diabetes mellitust yp...
# 2  beverage brainstem aura blindness field thria ...
# 3  kidney proteinuria found overload proteinuria ...
# 4  chapter ated bp reading office pharmacy coat o...
# 5  chapter per redness swelling conjunctiva compr...
#
#                             Topic
# 0                          Cancer
# 1                        Diabetes
# 2                  Nervous System
# 3                  Kidney Disease
# 4                    Hypertension
# 5  Ear, Nose, & Throat Disorders

# %% [markdown]
# ### Word Embedding

# %%
df02['string_values']
# Out:
# 0    prevention health promotion tobacco tobacco ht...
# 1    diabetes life islet west diabetes mellitust yp...
# 2    beverage brainstem aura blindness field thria ...
# 3    kidney proteinuria found overload proteinuria ...
# 4    chapter ated bp reading office pharmacy coat o...
# 5    chapter per redness swelling conjunctiva compr...
# Name: string_values, dtype: object

# %%
# Create a CountVectorizer for parsing/counting words
count_vectorizer = CountVectorizer(stop_words=stop_words)

doc_word_cv = count_vectorizer.fit_transform(df02['string_values'])
# Out:
# c:\Users\HP\anaconda3\envs\Oil_spill_dec\Lib\site-packages\sklearn\feature_extraction\text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['00', '10', '12', '120', '144', '15', '184', '185', '1l', '20', '200', '2016', '2017', '2020', '2021', '2022', '2022be', '2022hyp', '2022p', '2022redu', '2022whi', '217', '25', '261', '28', '283', '286', '30', '300', '31864827', '34', '35', '40', '50', '62', '640', '65', '68', '70', '7300', '77', '78', '85', '86', '90', '91', '967', '98', '99', 'ab', 'abcd2s', 'abd', 'abdo', 'abdom', 'abdomi', 'abdu', 'abn', 'abnor', 'abnormali', 'abnormaliti', 'abs', 'absorp', 'acc', 'accu', 'activ', 'ad', 'addi', 'additi', 'adenocar', 'adenocarci', 'ad
 'complicationsur', 'compromis', 'con', 'concen', 'concurr', 'condary', 'condi', 'conjunc', 'conjuncti', 'consecu', 'consid', 'consider', 'considerationsdiab', 'considerationso', 'considerationssa', 'consis', 'consist', 'contami', 'contem', 'contin', 'contra', 'controv', 'correc', 'corticoste', 'coun', 'cour', 'cr', 'cryoglobulin', 'ct', 'ctal', 'ctious', 'ctiv', 'ctroch', 'ctrolyt', 'cultur', 'cum', 'cumula', 'cun', 'curr', 'cy', 'cyclo', 'cyclophospha', 'cystec', 'cytochrom', 'cytore', 'dacryocystorhi', 'daily150', 'daily30', 'daily50', 'de', 'dec', 'defi', 'defini', 'degen', 'degenera', 'deglude', 'dehis', 'dehy', 'del', 'dele', 'demon', 'demyelin', 'demyelinati', 'den', 'denerva', 'densi', 'depriva', 'dequ', 'desir', 'dest', 'det', 'det ...
#   warnings.warn(

# %%
pd.DataFrame(doc_word_cv.toarray(), index=df02['Topic'], columns = count_vectorizer.get_feature_names_out()).head()
# Out:
#                 aa  aaa  ab  abbreviated  abcd  abdomen  abdomyolysis  \
# Topic
# Cancer           1    0   0            0     0       11             0
# Diabetes         0    0   0            0     0        0             0
# Nervous System   0    0   0            0     0        0             0
# Kidney Disease   5    0   0            1     0        0             1
# Hypertension     2    2   3            0     1        1             0
#
#                 abdomyolysise  abducens  abduction  ...  ºmultisystem  \
# Topic                                               ...
# Cancer                      0         0          0  ...             0
# Diabetes                    0         0          0  ...             0
# Nervous System              0         1          0  ...             0
# Kidney Disease              1         0          0  ...             1
# Hypertension                0         0          0  ...             0
#
#                 ºnephrotic  ºnonatherosclerotic  ºperipheral  ºprimary  \
# Topic
# Cancer                   0                    0            0         1
# Diabetes                 0                    0            0         0
# Nervous System           0                    0            1         0
# Kidney Disease           2                    0            0         0
# Hypertension             0                    1            0         0
#
#                 ºshocke  ºthe  ºtubulointerstitial  ºtypes  ºvenous
# Topic
# Cancer                0     0                    0       1        0
# Diabetes              0     1                    0       0        0
# Nervous System        0     0                    0       0        0
# Kidney Disease        0     0                    1       0        0
# Hypertension          1     0                    0       0        1
#
# [5 rows x 8634 columns]

# %%
# Create a TfidfVectorizer for parsing/counting words
tfidf = TfidfVectorizer(stop_words=stop_words)

doc_word_tfidf = tfidf.fit_transform(df02['string_values'])
# Out:
# c:\Users\HP\anaconda3\envs\Oil_spill_dec\Lib\site-packages\sklearn\feature_extraction\text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['00', '10', '12', '120', '144', '15', '184', '185', '1l', '20', '200', '2016', '2017', '2020', '2021', '2022', '2022be', '2022hyp', '2022p', '2022redu', '2022whi', '217', '25', '261', '28', '283', '286', '30', '300', '31864827', '34', '35', '40', '50', '62', '640', '65', '68', '70', '7300', '77', '78', '85', '86', '90', '91', '967', '98', '99', 'ab', 'abcd2s', 'abd', 'abdo', 'abdom', 'abdomi', 'abdu', 'abn', 'abnor', 'abnormali', 'abnormaliti', 'abs', 'absorp', 'acc', 'accu', 'activ', 'ad', 'addi', 'additi',
compl', 'comple', 'compli', 'complica', 'complicationsur', 'compromis', 'con', 'concen', 'concurr', 'condary', 'condi', 'conjunc', 'conjuncti', 'consecu', 'consid', 'consider', 'considerationsdiab', 'considerationso', 'considerationssa', 'consis', 'consist', 'contami', 'contem', 'contin', 'contra', 'controv', 'correc', 'corticoste', 'coun', 'cour', 'cr', 'cryoglobulin', 'ct', 'ctal', 'ctious', 'ctiv', 'ctroch', 'ctrolyt', 'cultur', 'cum', 'cumula', 'cun', 'curr', 'cy', 'cyclo', 'cyclophospha', 'cystec', 'cytochrom', 'cytore', 'dacryocystorhi', 'daily150', 'daily30', 'daily50', 'de', 'dec', 'defi', 'defini', 'degen', 'degenera', 'deglude', 'dehis', 'dehy', 'del', 'dele', 'demon', 'demyelin', 'demyelinati', 'den', 'denerva', 'densi', 'depriva', 'dequ', 'desir', 'dest', 'det', 'det ...
#   warnings.warn(

# %%
pd.DataFrame(doc_word_tfidf.toarray(), index=df02['Topic'], columns = tfidf.get_feature_names_out()).head()
# Out:
#                       aa       aaa        ab  abbreviated      abcd   abdomen  \
# Topic
# Cancer          0.001125  0.000000  0.000000     0.000000  0.000000  0.017107
# Diabetes        0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# Nervous System  0.000000  0.000000  0.000000     0.000000  0.000000  0.000000
# Kidney Disease  0.017186  0.000000  0.000000     0.005794  0.000000  0.000000
# Hypertension    0.005934  0.010003  0.015004     0.000000  0.005001  0.004101
#
#                 abdomyolysis  abdomyolysise  abducens  abduction  ...  \
# Topic                                                             ...
# Cancer              0.000000       0.000000  0.000000        0.0  ...
# Diabetes            0.000000       0.000000  0.000000        0.0  ...
# Nervous System      0.000000       0.000000  0.004431        0.0  ...
# Kidney Disease      0.005794       0.005794  0.000000        0.0  ...
# Hypertension        0.000000       0.000000  0.000000        0.0  ...
#
#                 ºmultisystem  ºnephrotic  ºnonatherosclerotic  ºperipheral  \
# Topic
# Cancer              0.000000    0.000000             0.000000     0.000000
# Diabetes            0.000000    0.000000             0.000000     0.000000
# Nervous System      0.000000    0.000000             0.000000     0.004431
# Kidney Disease      0.005794    0.011588             0.000000     0.000000
# Hypertension        0.000000    0.000000             0.005001     0.000000
#
#                 ºprimary   ºshocke      ºthe  ºtubulointerstitial    ºtypes  \
# Topic
# Cancer          0.001897  0.000000  0.000000             0.000000  0.001897
# Diabetes        0.000000  0.000000  0.008903             0.000000  0.000000
# Nervous System  0.000000  0.000000  0.000000             0.000000  0.000000
# Kidney Disease  0.000000  0.000000  0.000000             0.005794  0.000000
# Hypertension    0.000000  0.005001  0.000000             0.000000  0.000000
#
#                  ºvenous
# Topic
# Cancer          0.000000
# Diabetes        0.000000
# Nervous System  0.000000
# Kidney Disease  0.000000
# Hypertension    0.005001
#
# [5 rows x 8634 columns]

# %% [markdown]
# ### Topic Modeling: **LDA**

# %%
# Convert sparse matrix of counts to a gensim corpus
corpus = matutils.Sparse2Corpus(doc_word_cv)

# %%
id2word = dict((v, k) for k, v in count_vectorizer.vocabulary_.items())

# %%
# Create lda model (equivalent to "fit" in sklearn)
lda = models.LdaModel(corpus=corpus, num_topics=6, id2word=id2word, passes=5)

# %%
lda.print_topics(7)
# Out:
# [(0,
#   '0.611*"aa" + 0.316*"abcd" + 0.004*"ab" + 0.003*"abdomen" + 0.002*"abbreviated" + 0.001*"aaa" + 0.000*"philia" + 0.000*"phlebitis" + 0.000*"phomas" + 0.000*"phila"'),
#  (1,
#   '0.670*"aaa" + 0.003*"abcd" + 0.000*"abdomen" + 0.000*"aa" + 0.000*"abbreviated" + 0.000*"ab" + 0.000*"philia" + 0.000*"phlebitis" + 0.000*"phomas" + 0.000*"phila"'),
#  (2,
#   '0.000*"abcd" + 0.000*"abbreviated" + 0.000*"aaa" + 0.000*"ab" + 0.000*"abdomen" + 0.000*"aa" + 0.000*"philia" + 0.000*"phlebitis" + 0.000*"phomas" + 0.000*"phila"'),
#  (3,
#   '0.000*"abcd" + 0.000*"aaa" + 0.000*"aa" + 0.000*"ab" + 0.000*"abdomen" + 0.000*"abbreviated" + 0.000*"philia" + 0.000*"phlebitis" + 0.000*"phomas" + 0.000*"phila"'),
#  (4,
#   '0.841*"ab" + 0.015*"abdomen" + 0.005*"abcd" + 0.000*"aaa" + 0.000*"aa" + 0.000*"abbreviated" + 0.000*"philia" + 0.000*"phlebitis" + 0.000*"phomas" + 0.000*"phila"'),
#  (5,
#   '0.539*"abdomen" + 0.328*"abbreviated" + 0.002*"abcd" + 0.001*"aa" + 0.000*"ab" + 0.000*"aaa" + 0.000*"philia" + 0.000*"phlebitis" + 0.000*"phomas" + 0.000*"phila"')]

# %% [markdown]
# ### Performing CorEx:

# %%
from corextopic import corextopic as ct
from corextopic import vis_topic as vt

words = list(np.asarray(count_vectorizer.get_feature_names_out()))

# %%
topic_model = ct.Corex(n_hidden=6, words=words, seed=1)
topic_model.fit(doc_word_cv, words=words, docs=df02['string_values'])
# Out:
# WARNING: Some words never appear (or always appear)

# %%
topics = topic_model.get_topics()
for n,topic in enumerate(topics):
    topic_words,_,_ = zip(*topic)
    print('{}: '.format(n) + ','.join(topic_words))
# Out:
# 0: phenytoin,characterized,hospital,analog,fetus,vasospasm,radiating,stimulating,steal,reflect
# 1: bedtime,advised,extremely,swelling,betes,ingestion,staging,construction,phosphorus,transformation
# 2: length,tenderness,concern,sleep,blindness,kept,shift,atherosclerosis,burning,ifosfamide
# 3: canagliflozin,bind,atlas,na,sm,ace,voice,ke,ganglion,drained
# 4: novo,icu,ckd,cardiol,lism,acidosis,preservation,excision,structure,alopecia
# 5: transplantation,doubling,occult,algorithm,bound,load,alt,assay,presented,cardiovasc

# %% [markdown]
# ### Topic Modeling: LSA

# %%
lsa = TruncatedSVD(6)
doc_topic = lsa.fit_transform(doc_word_cv)
print(lsa.explained_variance_ratio_)
# Out:
# [0.62864254 0.1057321  0.09450078 0.08058466 0.05872876 0.03181116]

# %%
topic_word = pd.DataFrame(lsa.components_.round(6),
             index = ['component'+str(i) for i in range(6)],
             columns = count_vectorizer.get_feature_names_out())

topic_word.head()
# Out:
#                   aa       aaa        ab  abbreviated      abcd   abdomen  \
# component0  0.001717  0.000246  0.000370     0.000056  0.000123  0.012531
# component1  0.005000  0.002852  0.004278     0.000379  0.001426 -0.003332
# component2 -0.010933 -0.003888 -0.005832    -0.001261 -0.001944 -0.001737
# component3 -0.001817 -0.002429 -0.003644    -0.000589 -0.001215 -0.001174
# component4  0.015781 -0.003661 -0.005491     0.003890 -0.001830 -0.002733
#
#             abdomyolysis  abdomyolysise  abducens  abduction  ...  \
# component0      0.000056       0.000056  0.000142   0.000125  ...
# component1      0.000379       0.000379  0.001584   0.001369  ...
# component2     -0.001261      -0.001261  0.002470  -0.001515  ...
# component3     -0.000589      -0.000589 -0.000204   0.007108  ...
# component4      0.003890       0.003890  0.000595   0.000147  ...
#
#             ºmultisystem  ºnephrotic  ºnonatherosclerotic  ºperipheral  \
# component0      0.000056    0.000112             0.000123     0.000142
# component1      0.000379    0.000758             0.001426     0.001584
# component2     -0.001261   -0.002523            -0.001944     0.002470
# component3     -0.000589   -0.001178            -0.001215    -0.000204
# component4      0.003890    0.007780            -0.001830     0.000595
#
#             ºprimary   ºshocke      ºthe  ºtubulointerstitial    ºtypes  \
# component0  0.001128  0.000123  0.000049             0.000056  0.001128
# component1 -0.000433  0.001426  0.000479             0.000379 -0.000433
# component2  0.000019 -0.001944 -0.000285            -0.001261  0.000019
# component3  0.000004 -0.001215 -0.000317            -0.000589  0.000004
# component4 -0.000082 -0.001830  0.000224             0.003890 -0.000082
#
#              ºvenous
# component0  0.000123
# component1  0.001426
# component2 -0.001944
# component3 -0.001215
# component4 -0.001830
#
# [5 rows x 8634 columns]

# %%
tem_list = [] 
def display_topics(model, feature_names, no_top_words, topic_names=None):
    
    for ix, topic in enumerate(model.components_):
        inner_tem_list = []
       
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
            
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        inner_tem_list.append(", ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        tem_list.append(inner_tem_list)

# %%
result1 = display_topics(lsa, count_vectorizer.get_feature_names_out(), 20)
# Out:
# Topic  0
# cancer, tumor, survival, carcinoma, prostate, metastasis, resection, screening, nausea, ct, radiation, orally, men, agent, psa, combination, inhibitor, liver, diarrhea, node
#
# Topic  1
# artery, seizure, hg, study, kidney, weakness, brain, three, agent, ace, table, given, diabetes, minute, leg, trial, ct, inhibitor, vessel, mri
#
# Topic  2
# seizure, weakness, brain, mri, dementia, ct, epilepsy, ataxia, tumor, impairment, nausea, given, brainstem, relapse, depending, gene, basis, deficit, disability, alzheimer
#
# Topic  3
# drop, glaucoma, vision, solution, occlusion, uveitis, keratitis, cataract, detachment, hemorrhage, disk, four, cornea, lens, conjunctivitis, referred, ophthalmol, degeneration, laser, herpes
#
# Topic  4
# ckd, gfr, aki, eskd, dialysis, cyst, kidney, plasma, hematuria, seizure, iga, acidosis, tract, phosphorus, obstruction, sodium, laboratory, dis, vasculitis, microscopy
#
# Topic  5
# study, kidney, given, unit, liver, glucose, dka, benefit, three, diabetes, pen, egfr, pmdiabetes, nph, diet, ldl, mody, islet, per, either

# %%
tem_list
final_dic = {}
final_dic["Cancer"] = tem_list[0]
final_dic["Diabetes"] = tem_list[1]
final_dic["Nervous System"] = tem_list[2]
final_dic["Kidney"] = tem_list[3]
final_dic["Hypertension"] = tem_list[4]
final_dic["Ear & Nose"] = tem_list[5]

# %%
final_dic
# Out:
# {'Cancer': ['cancer, tumor, survival, carcinoma, prostate, metastasis, resection, screening, nausea, ct, radiation, orally, men, agent, psa, combination, inhibitor, liver, diarrhea, node'],
#  'Diabetes': ['artery, seizure, hg, study, kidney, weakness, brain, three, agent, ace, table, given, diabetes, minute, leg, trial, ct, inhibitor, vessel, mri'],
#  'Nervous System': ['seizure, weakness, brain, mri, dementia, ct, epilepsy, ataxia, tumor, impairment, nausea, given, brainstem, relapse, depending, gene, basis, deficit, disability, alzheimer'],
#  'Kidney': ['drop, glaucoma, vision, solution, occlusion, uveitis, keratitis, cataract, detachment, hemorrhage, disk, four, cornea, lens, conjunctivitis, referred, ophthalmol, degeneration, laser, herpes'],
#  'Hypertension': ['ckd, gfr, aki, eskd, dialysis, cyst, kidney, plasma, hematuria, seizure, iga, acidosis, tract, phosphorus, obstruction, sodium, laboratory, dis, vasculitis, microscopy'],
#  'Ear & Nose': ['study, kidney, given, unit, liver, glucose, dka, benefit, three, diabetes, pen, egfr, pmdiabetes, nph, diet, ldl, mody, islet, per, either']}

# %%
tem_df = pd.DataFrame.from_dict(final_dic, orient ='index') 
tem_df
# Out:
#                                                                 0
# Cancer          cancer, tumor, survival, carcinoma, prostate, ...
# Diabetes        artery, seizure, hg, study, kidney, weakness, ...
# Nervous System  seizure, weakness, brain, mri, dementia, ct, e...
# Kidney          drop, glaucoma, vision, solution, occlusion, u...
# Hypertension    ckd, gfr, aki, eskd, dialysis, cyst, kidney, p...
# Ear & Nose      study, kidney, given, unit, liver, glucose, dk...

# %%
# Declare a list that is to be converted into a column
d_name = ['Cancer', 'Diabetes', 'Nervous System', 'Kidney', 'Hypertension', 'Ear & Nose']
 
# Using 'ch_no' as the column name
# and equating it to the list
tem_df['D_Name'] = d_name

# %%
tem_df.columns
# Out:
# Index([0, 'D_Name'], dtype='object')

# %%
tem_df = tem_df.rename(columns={0: 'Description'})
tem_df
# Out:
#                                                       Description  \
# Cancer          cancer, tumor, survival, carcinoma, prostate, ...
# Diabetes        artery, seizure, hg, study, kidney, weakness, ...
# Nervous System  seizure, weakness, brain, mri, dementia, ct, e...
# Kidney          drop, glaucoma, vision, solution, occlusion, u...
# Hypertension    ckd, gfr, aki, eskd, dialysis, cyst, kidney, p...
# Ear & Nose      study, kidney, given, unit, liver, glucose, dk...
#
#                         D_Name
# Cancer                  Cancer
# Diabetes              Diabetes
# Nervous System  Nervous System
# Kidney                  Kidney
# Hypertension      Hypertension
# Ear & Nose          Ear & Nose

# %%
tem_df.to_csv('description_of_deseases.csv', index=False)

# %%
import os
cwd = os.getcwd()
cwd
# Out:
# 'c:\\Users\\HP\\Downloads'
